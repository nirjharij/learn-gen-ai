# %% [markdown]
# <h1>Prompt Evaluation </h1>
#
#  - Measures prompt effectivenes by evaluating the LLM response on accuracy, relevancy etc
#  - Unit testing but for Natural language instructions
#
# There are two types of evaluation:
#
# **Manual Evaluation**  A human scores the output
#
# **Automated Evaluation** An LLM or algorithm scores the output
#
# <h2>Why we need Prompt Evaluation </h2>
#
#  - LLMs are non-deterministic and sensitive to wording. A small change in your prompt can **dramatically** change output quality for better or worse.
#
# Prompt evaluation lets you:
# 1. **Compare** prompt versions objectively
# 2. **Catch regressions** when models or prompts change
# 3. **Justify decisions** with data instead of opinion
# 4. **Iterate faster** by knowing exactly what's improving
#
# ## 📊 Metrics for Prompt Effectiveness
#
# We'll focus on **5 core metrics**
#
# | Metric | What it measures | Score Range |
# |--------|-----------------|-------------|
# | **Accuracy** | Is the information factually correct? | 0.0 – 1.0 |
# | **Relevance** | Does the response actually answer the question? | 0.0 – 1.0 |
# | **Completeness** | Are all important aspects covered? | 0.0 – 1.0 |
# | **Conciseness** | Is the response appropriately brief without losing value? | 0.0 – 1.0 |
# | **Clarity** | Is the response easy to understand? | 0.0 – 1.0 |
#
# An **overall score** is computed as the weighted average of all five metrics.

# %% [markdown]
# ---
# ## Section 1: Setup & Configuration

# %%
import json
import ollama
import textwrap
import time
from typing import List
import pandas as pd

# %% [markdown]
# ---
# ## Section 2: Define Our Test Cases
#
# We'll evaluate prompts on a single real-world task: **explaining a technical concept to a beginner audience**.

# %%
# ── Our test question ──────────────────────────────────────────────────────
QUESTION = """
    A customer purchased a laptop 8 months ago for €1200.
    The laptop battery has started swelling and overheating.
    
    The customer is angry because:
    - Warranty technically expired last week
    - Customer support previously ignored 2 emails
    - They need the laptop urgently for work
    
    Write a customer support response email.
"""

# Key elements a high-quality response should include
REFERENCE_POINTS = [
    "Acknowledges the customer's frustration empathetically",
    "Clearly addresses the battery safety concern",
    "Offers a concrete next step or resolution",
    "Avoids sounding robotic or defensive",
    "Maintains a professional and calm tone",
    "Mentions urgency and prioritizes the case",
    "Does not blindly reject the request because warranty expired",
    "Keeps the response concise and readable",
]

# ── Generic prompt (weak prompt) ───────────────────────────────────────────
generic_prompt = """
    Write a customer support response email.
     A customer purchased a laptop 8 months ago for €1200.
    The laptop battery has started swelling and overheating.
    
    The customer is angry because:
    - Warranty technically expired last week
    - Customer support previously ignored 2 emails
    - They need the laptop urgently for work
"""

# ── Optimized prompt (best practices applied) ──────────────────────────────
# Best practices used:
#   1. Explicit role/persona
#   2. Emotional context handling
#   3. Structured objectives
#   4. Tone constraints
#   5. Safety/brand-awareness
#   6. Anti-pattern instructions
#   7. Output length guidance

optimized_prompt = """
    You are a senior customer support specialist for a premium electronics company.
    
    Write a response email to the customer described below.
    
    Customer situation:
    - Purchased a laptop 8 months ago for €1200
    - Battery is swelling and overheating
    - Warranty expired last week
    - Customer support ignored 2 previous emails
    - Customer urgently needs the laptop for work
    
    Your goals:
    1. Acknowledge the frustration empathetically
    2. Treat the battery issue as a serious safety concern
    3. Avoid blaming policy or focusing on warranty expiration
    4. Offer a concrete next step the customer can take immediately
    5. Prioritize urgency and rebuild trust
    
    Tone requirements:
    - Professional
    - Human
    - Calm
    - Reassuring
    - NOT robotic or overly corporate
    
    Constraints:
    - Keep the email under 220 words
    - Do not use phrases like:
      - "We apologize for the inconvenience"
      - "As per company policy"
      - "Unfortunately your warranty has expired"
    
    End with a clear action-oriented resolution.
"""

eval_cases = [{"prompt_text": generic_prompt, "prompt_label": "Generic Prompt"}, 
              {"prompt_text": optimized_prompt, "prompt_label": "Optimized Prompt"}]

# %% [markdown]
# ---
# ## Section 3: Generate Model Responses

# %%
MODEL = "llama3"

# ── Helper: call the model ──────────────────────────────────────────────────
def query_model(prompt: str, system: str = "") -> str:
    """Send a prompt to Model and return the text response."""
    messages = [{"role": "user", "content": prompt}]
    if system:
        messages.append({"role": "system", "content": system})
    kwargs = {"model": MODEL, "messages": messages}
    response = ollama.chat(**kwargs)
    return response["message"]["content"]


# ── Helper: pretty-print a response ────────────────────────────────────────
def display_response(label: str, text: str, width: int = 90) -> None:
    border = "─" * width
    print(f"\n┌{border}┐")
    print(f"│ {label:<{width-1}}│")
    print(f"├{border}┤")
    for line in textwrap.wrap(text, width - 2):
        print(f"│ {line:<{width-1}}│")
    print(f"└{border}┘")

df_data = {}

# %% [markdown]
# ---
# ## Section 4: Manual Evaluation (Human-in-the-Loop)
#
# ### Scoring Rubric (0.0 – 1.0 per metric)
#
# | Score | Meaning |
# |-------|---------|
# | 0.0 – 0.3 | Poor – major issues |
# | 0.4 – 0.6 | Acceptable – some issues |
# | 0.7 – 0.8 | Good – minor issues |
# | 0.9 – 1.0 | Excellent – meets all criteria |
#
# **Accuracy**: Cross-check against the reference points above.
# **Relevance**: Does it answer the actual question without going off-topic?
# **Completeness**: How many reference points are covered?
# **Conciseness**: Is it appropriately brief, or padded/too terse?
# **Clarity**: Could a beginner genuinely understand this?

# %%
METRICS = ["accuracy", "relevance", "completeness", "conciseness", "clarity"]

def overall(accuracy=0, relevance=0, completeness=0, conciseness=0, clarity=0) -> float:
    weights = {"accuracy": 0.30, "relevance": 0.25,
               "completeness": 0.20, "conciseness": 0.10, "clarity": 0.15}
    return round(
        accuracy    * weights["accuracy"]    +
        relevance   * weights["relevance"]   +
        completeness * weights["completeness"] +
        conciseness * weights["conciseness"] +
        clarity     * weights["clarity"],
        3
    )

def manual_evaluation(metrics):
    scores = {}
    for metric in metrics:
        score = float(input(f"Score for {metric} (0-1): "))
        print(f"{metric}: {score}")
        scores[metric] = score
    return scores

print("Querying model for each prompt...\n")

for case in eval_cases:
    prompt = case["prompt_text"]
    prompt_label = case['prompt_label']
    print(f"\n Evaluating {prompt_label}")
    response = query_model(prompt)
    display_response(f"{prompt_label}", response)
    scores = manual_evaluation(METRICS)
    overall_score = overall(**scores)
    print(f"Overall Score after Manual Evaluation: {overall_score}")
    scores["overall"] = overall_score
    df_data[("Human Evaluation", prompt_label)] = scores

print("\n Responses generated.")

# %% [markdown]
# ---
# ## Section 5: Automated Evaluation (LLM-as-Judge)
#
# Manual evaluation doesn't scale. When you have dozens of prompts and hundreds of test cases, you need automation.
#
# **LLM-as-Judge** is the industry standard approach: you ask a capable language model to evaluate another model's output using a structured rubric.

# %%
JUDGE_SYSTEM_PROMPT = """You are an impartial evaluation assistant. Your job is to score 
AI responses on a set of quality dimensions. You MUST respond with valid JSON only — 
no preamble, no markdown fences, no extra text."""

def build_judge_prompt(question: str, response: str, reference_points: List[str]) -> str:
    ref_list = "\n".join(f"- {rp}" for rp in reference_points)
    return f"""Evaluate the following AI response to the question below.

        QUESTION:
        {question}
        
        REFERENCE KEY POINTS (a high-quality answer should cover these):
        {ref_list}
        
        AI RESPONSE TO EVALUATE:
        {response}
        
        Score the response on each dimension from 0.0 to 1.0:
        
        - accuracy: Are the facts stated correct and free from errors?
        - relevance: Does the response directly address the question without going off-topic?
        - completeness: How many of the reference key points are adequately covered?
        - conciseness: Is the length appropriate — not padded, not too terse?
        - clarity: Is the language clear and accessible to the intended audience?
        
        Return ONLY a JSON object like this:
        {{
          "accuracy": <float>,
          "relevance": <float>,
          "completeness": <float>,
          "conciseness": <float>,
          "clarity": <float>,
          "reasoning": "<1-2 sentence explanation of your scores>"
        }}"""

def automated_evaluation(prompt, response):
    judge_prompt = build_judge_prompt(
        prompt, response, REFERENCE_POINTS
    )
    raw = query_model(judge_prompt, system=JUDGE_SYSTEM_PROMPT)
    
    # Strip markdown fences if the model adds them
    raw = raw.strip().lstrip("```json").lstrip("```").rstrip("```").strip()
    data = json.loads(raw)
    return {
        "accuracy": data["accuracy"],
        "relevance": data["relevance"],
        "completeness": data["completeness"],
        "conciseness": data["conciseness"],
        "clarity": data["clarity"],
    }

for case in eval_cases:
    prompt = case["prompt_text"]
    prompt_label = case['prompt_label']
    print(f"\n Evaluating {prompt_label}")
    response = query_model(prompt)
    display_response(f"{prompt_label}", response)
    scores = automated_evaluation(prompt, response)
    overall_score = overall(**scores)
    print(f"Overall Score after Automated Evaluation: {overall_score}")
    scores["overall"] = overall_score
    df_data[("Automated Evaluation", prompt_label)] = scores
    time.sleep(1) 

print("\n Responses generated.")
# Out:
#  Evaluating Generic Prompt
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────┐
# │ Generic Prompt                                                                           │
# ├──────────────────────────────────────────────────────────────────────────────────────────┤
# │ Here's an example of a cover letter for a software engineer applying to a startup:       │
# │ [Your Name] [Your Address] [City, State ZIP Code] [Date]  [Hiring Manager's Name]        │
# │ [Startup Company Name] [Company Address] [City, State ZIP Code]  Dear [Hiring Manager's  │
# │ Name],  I'm excited to apply for the Software Engineer position at [Startup Company      │
# │ Name], as advertised on [Job Board/Source]. With a passion for building innovative       │
# │ products and a strong foundation in software engineering, I believe I would be an        │
# │ excellent fit for your team.  As a highly motivated and detail-oriented individual, I've │
# │ developed a unique blend of technical skills and problem-solving abilities throughout my │
# │ career. My experience in [specific programming languages or technologies] has allowed me │
# │ to effectively design, develop, test, and deploy scalable software solutions that meet   │
# │ the needs of diverse user bases. I'm confident that my skills will enable me to make     │
# │ significant contributions to your team's projects.  What drew me to [Startup Company     │
# │ Name] is the company's commitment to [aspect of startup's mission or values that         │
# │ resonates with you]. As someone who thrives in a fast-paced, collaborative environment,  │
# │ I appreciate the startup's focus on [specific area of innovation or growth]. I'm excited │
# │ about the opportunity to join a team that shares my passion for pushing boundaries and   │
# │ creating positive impact.  In addition to my technical expertise, I bring a strong work  │
# │ ethic, excellent communication skills, and a willingness to continuously learn and       │
# │ improve. My experience in [related field or industry] has provided me with a solid       │
# │ understanding of the importance of collaboration, adaptability, and creative problem-    │
# │ solving in today's rapidly evolving tech landscape.  I've attached my resume, which      │
# │ provides more details on my technical skills, experience, and achievements. I'd love the │
# │ opportunity to discuss how my skills align with your team's needs and how I can          │
# │ contribute to the company's continued growth and success.  Thank you for considering my  │
# │ application. I look forward to hearing from you soon!  Sincerely,  [Your Name]  Remember │
# │ to:  1. Customize the letter to fit your own experiences and qualifications. 2. Research │
# │ the startup company, including its mission, values, and current projects. 3. Highlight   │
# │ your relevant skills, experience, and achievements. 4. Show enthusiasm for the company   │
# │ and role, but avoid being overly generic or clichéd. 5. Use a professional tone and      │
# │ formatting throughout the letter.  Best of luck with your application!                   │
# └──────────────────────────────────────────────────────────────────────────────────────────┘
# Overall Score after Automated Evaluation: 0.938
#
#  Evaluating Optimized Prompt
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────┐
# │ Optimized Prompt                                                                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┤
# │ Here is the cover letter:  Dear NovaPay Team,  When I heard about NovaPay's mission to   │
# │ revolutionize real-time payment infrastructure, my mind went into overdrive thinking     │
# │ about the massive impact this could have on the fintech landscape - and how I can        │
# │ contribute to making it a reality.  As a seasoned backend engineer with 4 years of       │
# │ experience in Python and distributed systems, I'm excited to highlight two specific      │
# │ achievements that showcase my skills. At my previous company, I reduced API latency by   │
# │ 40% using a combination of caching and async processing, resulting in significant        │
# │ performance improvements. I also led a team of 3 engineers to develop a scalable payment │
# │ processing system, where we increased throughput by 300%. These experiences not only     │
# │ honed my technical expertise but also taught me the importance of collaboration and      │
# │ problem-solving under pressure - skills that would be invaluable at NovaPay.  What truly │
# │ excites me about NovaPay is the company's commitment to real-time payments, which aligns │
# │ with my passion for building scalable and efficient systems. I'm impressed by NovaPay's  │
# │ innovative approach to solving complex payment processing challenges and believe my      │
# │ expertise in distributed systems could make a tangible difference in your mission. I'm   │
# │ eager to contribute my skills and experience to help drive the company's growth and      │
# │ success.  I'd love the opportunity to discuss how my skills can support NovaPay's        │
# │ ambitious plans. Thank you for considering my application. I look forward to the chance  │
# │ to chat more about this exciting role!  Best regards, [Your Name]                        │
# └──────────────────────────────────────────────────────────────────────────────────────────┘
# Overall Score after Automated Evaluation: 0.938
#
#  Responses generated.

# %% [markdown]
# ---
# ## Section 6: Comparing the Results

# %%
df = pd.DataFrame(df_data)
# Round values for cleaner display
df = df.round(2)

# Display nicely in Jupyter Notebook
display(df)
# Out:
#              Human EValuation                  Automated EValuation  \
#                Generic Prompt Optimized Prompt       Generic Prompt
# accuracy                 0.50             0.90                 1.00
# relevance                0.60             0.90                 0.90
# completeness             0.40             0.90                 0.95
# conciseness              0.70             0.80                 0.80
# clarity                  0.80             0.80                 0.95
# overall                  0.57             0.88                 0.94
#
#
#              Optimized Prompt
# accuracy                 1.00
# relevance                0.90
# completeness             0.95
# conciseness              0.80
# clarity                  0.95
# overall                  0.94
